# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
from numpy.lib.type_check import nan_to_num
countries = pd.read_csv("lds4.csv", na_values="#N/A")
countries.head(15)
# Out:
#     no                   Country     Region  population  birth rate per 1000  \
# 0    1                   Algeria  Africa, N    41657488                 21.5
# 1    2                     Egypt  Africa, N    99413317                 28.8
# 2    3                     Libya  Africa, N     6754507                 17.2
# 3    4                   Morocco  Africa, N    34314130                 17.5
# 4    5                     Sudan  Africa, N    43120843                 34.2
# 5    6                   Tunisia  Africa, N    11516189                 17.4
# 6    7            Western Sahara  Africa, N      619551                 28.9
# 7    8                    Angola  Africa, S    30355880                 43.7
# 8    9                     Benin  Africa, S    11340504                 34.5
# 9   10                  Botswana  Africa, S     2249104                 21.7
# 10  11              Burkina Faso  Africa, S    19742715                 36.9
# ...

# %%
fig = px.scatter_matrix(countries, ["unemployment 3(%)", "GDP per capita (US$)", "Total area"], color="Country")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
